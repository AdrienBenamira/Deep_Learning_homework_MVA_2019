# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization, Flatten
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# The act function takes as input the state of the game at t as well as the mode (training or evaluation) to return the action to be performed at t+1. This function use an $\epsilon$-greedy strategy and actually tackles the exploration-exploitation dilemma.
#
# __In the case of training__, two cases are possible. Either, case 1, the action is chosen at random for exploration purposes. Either, case 2, the action is predicted from the state and level of knowledge of the network (poor at the beginning, rich at the end). And the parameter ```epsilon``` is essential in the choice of case 1 or 2. This is the $\epsilon$-greedy strategy. We observe that if ```epsilon``` = 0, then we will alxays be in case 2 and if ```epsilon``` =1, then we will be always in case 1.
#
# ```Epsilon``` is essential especially because if the return of the ```learned_act``` is poor and stuck in one action, the diversity will come from the case 1. That's why we call it discorvery parameter

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus
        
        
        self.board[:2,:] = 0
        self.board[-2:,:] = 0
        self.board[:, :2] = 0
        self.board[:, -2:] = 0


        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=100 # set small when debugging
epochs_test=50 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# ```position``` is an array of shape (grid_size x grid_size) representing where the rat can go.
# The rat is on case where the value is 1.
# It can not go on case where there is a -1.
# It can go on case where there is a 0.
#
# ```board``` is an array of shape grid_size x grid_size representing the reward associated to each cell of the grid. The rat on case $(x,y)$ will get the reward board[x,y]. There is a -0.5 if there is a negative reward (malus), 1 if there is a positive reward (bonus) and 0 if there is no reward  .

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(0, self.n_action)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):        
        state = env.reset()
        win = 0
        lose = 0
        game_over = False
        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward
        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 15.0/14.0. Average score (1.0)
# Win/lose count 11.5/5.0. Average score (3.75)
# Win/lose count 9.0/14.0. Average score (0.8333333333333334)
# Win/lose count 12.0/14.0. Average score (0.125)
# Win/lose count 6.0/14.0. Average score (-1.5)
# Win/lose count 9.0/7.0. Average score (-0.9166666666666666)
# Win/lose count 12.5/15.0. Average score (-1.1428571428571428)
# Win/lose count 8.0/14.0. Average score (-1.75)
# Win/lose count 5.5/11.0. Average score (-2.1666666666666665)
# Win/lose count 8.5/12.0. Average score (-2.3)
# Win/lose count 8.5/11.0. Average score (-2.3181818181818183)
# Win/lose count 7.5/14.0. Average score (-2.6666666666666665)
# Win/lose count 13.0/11.0. Average score (-2.3076923076923075)
# Win/lose count 8.0/20.0. Average score (-3.0)
# Win/lose count 7.5/9.0. Average score (-2.9)
# Win/lose count 9.0/16.0. Average score (-3.15625)
# Win/lose count 11.0/11.0. Average score (-2.9705882352941178)
# Win/lose count 8.5/10.0. Average score (-2.888888888888889)
# Win/lose count 8.5/12.0. Average score (-2.9210526315789473)
# Win/lose count 11.0/19.0. Average score (-3.175)
# Win/lose count 13.5/10.0. Average score (-2.857142857142857)
# Win/lose count 5.0/11.0. Average score (-3.0)
# Win/lose count 9.5/15.0. Average score (-3.108695652173913)
# Win/lose count 11.0/20.0. Average score (-3.3541666666666665)
# Win/lose count 11.5/20.0. Average score (-3.56)
# Win/lose count 13.0/17.0. Average score (-3.576923076923077)
# Win/lose count 7.5/6.0. Average score (-3.388888888888889)
# Win/lose count 10.0/20.0. Average score (-3.625)
# Win/lose count 9.0/16.0. Average score (-3.7413793103448274)
# Win/lose count 9.0/10.0. Average score (-3.65)
# Win/lose count 12.5/20.0. Average score (-3.774193548387097)
# Win/lose count 11.5/16.0. Average score (-3.796875)
# Win/lose count 13.5/13.0. Average score (-3.6666666666666665)
# Win/lose count 11.0/14.0. Average score (-3.6470588235294117)
# Win/lose count 12.5/10.0. Average score (-3.4714285714285715)
# Win/lose count 11.0/13.0. Average score (-3.4305555555555554)
# Win/lose count 9.5/12.0. Average score (-3.4054054054054053)
# Win/lose count 11.0/11.0. Average score (-3.3157894736842106)
# Win/lose count 10.5/18.0. Average score (-3.423076923076923)
# Win/lose count 7.5/14.0. Average score (-3.5)
# Win/lose count 5.5/4.0. Average score (-3.3780487804878048)
# Win/lose count 13.5/23.0. Average score (-3.5238095238095237)
# Win/lose count 9.0/22.0. Average score (-3.744186046511628)
# Win/lose count 11.0/15.0. Average score (-3.75)
# Win/lose count 13.5/19.0. Average score (-3.7888888888888888)
# Win/lose count 9.0/16.0. Average score (-3.858695652173913)
# Win/lose count 9.5/14.0. Average score (-3.872340425531915)
# Win/lose count 9.5/18.0. Average score (-3.96875)
# Win/lose count 10.0/18.0. Average score (-4.051020408163265)
# Win/lose count 8.5/18.0. Average score (-4.16)
# Final score: -4.16
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# -----------------------------------------------------------------
# 1/
#
# As seen in class we have (slide 55)
# $$ Q^{\pi}(s,a) = E_{\pi}[R_t |s_t = s, a_t = a] = E_\pi[\sum_{k=0}^{\infty} \gamma^k r_{t+k}|s_t = s, a_t = a] =
# E_\pi[ r(s,a) + \sum_{k=1}^{\infty} \gamma^k r_{t+k}|s_t = s, a_t = a]
# $$
#
# and with a changement of variable $j +1 = k$ we have :
# $$
# Q^{\pi}(s,a) = E_\pi[ r(s,a) + \sum_{j=0}^{\infty} \gamma^{j+1} r_{t+j+1}|s_t = s, a_t = a] \\ = r(s,a) + \gamma E_\pi[ \sum_{j=0}^{\infty} \gamma^{j} r_{t+j+1}|s_t = s, a_t = a]
# $$
#
# Thank to the propriety : $\mathbb E[X]=\mathbb E[\mathbb E[X|Y]]$, we have
#
# $$
# Q^{\pi}(s,a) = r(s,a) + \gamma  E_\pi[ E_\pi[ (\sum_{j=0}^{\infty} \gamma^{j} r_{t+j+1}|s_t = s, a_t = a)|s_{t+1} = s', a_{t+1} = a']]
# $$
# $$
# Q^{\pi}(s,a) = 1.r(s,a) + \gamma \sum_{(s',a')}p(s_{t+1}=s',a_{t+1}=a' |s_t = s, a_t = a )[E[\sum_{j=0}^{\infty}\gamma^j r_{(t+1)+j}|s_{t+1}=s',a_{t+1}=a']\\
# $$
#
# and because
# $$
# \sum_{(s',a')}p(s_{t+1}=s',a_{t+1}=a' |s_t = s, a_t = a ) = 1
# $$
# we have, thank to a factorisation :
#
# $$
# Q^{\pi}(s,a) = \sum_{(s',a')}p(s_{t+1}=s',a_{t+1}=a' |s_t = s, a_t = a ) [r(s,a) + \gamma E[\sum_{j=0}^{\infty}\gamma^j r_{(t+1)+j}|s_{t+1}=s',a_{t+1}=a']]\\
# = \sum_{(s',a')}p(s_{t+1}=s',a_{t+1}=a' |s_t = s, a_t = a ) [r(s,a) + \gamma Q^{\pi}(s',a')]
# = E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# $$
#
# --------------------------------------------------------------

# %% [markdown]
# 2/
#
# We have:
# $$
# \begin{equation}
# Q^*(s,a) = \max_{\pi} Q^{\pi}(s, a)
# \end{equation}
# $$
# so with
#
# $$\begin{align*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')] \end{align*}$$
#
# we get
# $$\begin{align*} Q^*(s,a) & = E_{(s',a')\sim \pi^*(.|s,a)}[r(s,a)+\gamma \max_{\pi} Q^{\pi}(s',a')] \\ & = E_{(s',a')\sim \pi^*(.|s,a)}[r(s,a)+\gamma Q^*(s',a')] \end{align*}$$
#
# and by defination of policy we have $s' \sim \pi^*(.|s,a)$ and so
#
# $$\begin{align*}
# Q^*(s,a) = \max_{\pi} Q^{\pi}(s,a) = E_{s' \sim \pi^*(.|s,a)}[r(s,a)+\gamma \max_{a'} Q^{*}(s',a')]
# \end{align*}$$
#
# -------------------------------------------------------

# %% [markdown]
# 3/
#
# If we want to approximate $Q^*(s,a)$ we should define the loss as :
#
# $$\begin{align*}
# L_i(\theta_i) = E_{s' \sim \pi^*(.|s,a)}[\Vert Q^*(s,a)- Q(s, a; \theta_i)\Vert^2]
# \end{align*}$$
#
# and thanks to last answer, we have :
#
# $$\begin{align*}
# Q^*(s,a) = E_{s' \sim \pi^*(.|s,a)}[r(s,a)+\gamma \max_{a'} Q^{*}(s',a')]
# \end{align*}$$
#
# Finally we have:
#
# \begin{align} \mathcal{L}(\theta)=E_{s' \sim \pi^(.|s,a)}[\Vert( r(s,a)+\gamma\max_{a'}Q(s',a',\theta{i-1})-Q(s,a,\theta_i))\Vert^2] \end{align}

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        if len(self.memory)<self.max_memory:
            self.memory.append(m)
            
    def random_access(self):
        tirage = np.random.randint(0, len(self.memory))
        return self.memory[tirage]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(s.reshape([1,s.shape[0],s.shape[1],s.shape[2]]))[0,:])

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            ######## FILL IN
            s_, n_s_, a_, r_, game_over_  = self.memory.random_access()
            
            target_q[i] =self.model.predict(s_.reshape([1,s_.shape[0],s_.shape[1],s_.shape[2]]))[0]
            
            input_states[i] = s_
            
            if game_over_:
                ######## FILL IN
                target_q[i,a_] = r_
            else:
                ######## FILL IN
                q_est = self.model.predict(np.expand_dims(n_s_, 0))
                target_q[i, a_] = r_ + self.discount * np.max(q_est)
                
                
        ######## FILL IN
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)
        l = self.model.train_on_batch(input_states, target_q)


        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        #Best model
        model = Sequential()
        model.add(Flatten(input_shape=(5,5,self.n_state,)))
        model.add(Dense(32,activation ='relu')) 
        model.add(Dense(4))
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 16)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train40.mp4'))
# Out:
# Epoch 000/100 | Loss 0.0038 | Win/lose count 2.0/8.0 (-6.0)
# Epoch 001/100 | Loss 0.0042 | Win/lose count 2.5/2.0 (0.5)
# Epoch 002/100 | Loss 0.0029 | Win/lose count 4.0/3.0 (1.0)
# Epoch 003/100 | Loss 0.0044 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 004/100 | Loss 0.0180 | Win/lose count 6.5/3.0 (3.5)
# Epoch 005/100 | Loss 0.0066 | Win/lose count 8.0/3.0 (5.0)
# Epoch 006/100 | Loss 0.0161 | Win/lose count 5.0/4.0 (1.0)
# Epoch 007/100 | Loss 0.0147 | Win/lose count 4.5/2.0 (2.5)
# Epoch 008/100 | Loss 0.0260 | Win/lose count 4.5/4.0 (0.5)
# Epoch 009/100 | Loss 0.0065 | Win/lose count 5.0/1.0 (4.0)
# Epoch 010/100 | Loss 0.0068 | Win/lose count 8.5/3.0 (5.5)
# Epoch 011/100 | Loss 0.0058 | Win/lose count 4.0/1.0 (3.0)
# Epoch 012/100 | Loss 0.0057 | Win/lose count 6.0/8.0 (-2.0)
# Epoch 013/100 | Loss 0.0076 | Win/lose count 3.0/2.0 (1.0)
# Epoch 014/100 | Loss 0.0034 | Win/lose count 4.0/6.0 (-2.0)
# Epoch 015/100 | Loss 0.0025 | Win/lose count 5.0/2.0 (3.0)
# Epoch 016/100 | Loss 0.0020 | Win/lose count 5.0/4.0 (1.0)
# Epoch 017/100 | Loss 0.0040 | Win/lose count 5.0/4.0 (1.0)
# Epoch 018/100 | Loss 0.0025 | Win/lose count 4.5/3.0 (1.5)
# Epoch 019/100 | Loss 0.0024 | Win/lose count 5.0/3.0 (2.0)
# Epoch 020/100 | Loss 0.0025 | Win/lose count 5.0/0 (5.0)
# Epoch 021/100 | Loss 0.0071 | Win/lose count 7.0/7.0 (0.0)
# Epoch 022/100 | Loss 0.0011 | Win/lose count 8.5/5.0 (3.5)
# Epoch 023/100 | Loss 0.0970 | Win/lose count 3.0/1.0 (2.0)
# Epoch 024/100 | Loss 0.0045 | Win/lose count 6.5/6.0 (0.5)
# Epoch 025/100 | Loss 0.0045 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 026/100 | Loss 0.0018 | Win/lose count 3.0/6.0 (-3.0)
# Epoch 027/100 | Loss 0.0007 | Win/lose count 7.5/2.0 (5.5)
# Epoch 028/100 | Loss 0.0019 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 029/100 | Loss 0.0016 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 030/100 | Loss 0.0012 | Win/lose count 1.0/1.0 (0.0)
# Epoch 031/100 | Loss 0.0016 | Win/lose count 5.5/4.0 (1.5)
# Epoch 032/100 | Loss 0.0008 | Win/lose count 3.5/1.0 (2.5)
# Epoch 033/100 | Loss 0.0006 | Win/lose count 9.0/6.0 (3.0)
# Epoch 034/100 | Loss 0.0014 | Win/lose count 2.0/1.0 (1.0)
# Epoch 035/100 | Loss 0.0057 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 036/100 | Loss 0.0019 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 037/100 | Loss 0.0014 | Win/lose count 6.5/1.0 (5.5)
# Epoch 038/100 | Loss 0.0027 | Win/lose count 7.0/4.0 (3.0)
# Epoch 039/100 | Loss 0.0016 | Win/lose count 6.5/3.0 (3.5)
# Epoch 040/100 | Loss 0.0015 | Win/lose count 5.5/5.0 (0.5)
# Epoch 041/100 | Loss 0.0078 | Win/lose count 5.0/3.0 (2.0)
# Epoch 042/100 | Loss 0.0039 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 043/100 | Loss 0.0008 | Win/lose count 5.0/3.0 (2.0)
# Epoch 044/100 | Loss 0.0012 | Win/lose count 11.0/5.0 (6.0)
# Epoch 045/100 | Loss 0.0031 | Win/lose count 4.0/4.0 (0.0)
# Epoch 046/100 | Loss 0.0936 | Win/lose count 2.5/1.0 (1.5)
# Epoch 047/100 | Loss 0.0068 | Win/lose count 6.0/5.0 (1.0)
# Epoch 048/100 | Loss 0.0020 | Win/lose count 6.0/3.0 (3.0)
# Epoch 049/100 | Loss 0.0047 | Win/lose count 2.5/0 (2.5)
# Epoch 050/100 | Loss 0.0067 | Win/lose count 7.0/4.0 (3.0)
# Epoch 051/100 | Loss 0.0006 | Win/lose count 7.0/1.0 (6.0)
# Epoch 052/100 | Loss 0.0023 | Win/lose count 1.0/0 (1.0)
# Epoch 053/100 | Loss 0.0020 | Win/lose count 2.5/6.0 (-3.5)
# Epoch 054/100 | Loss 0.0027 | Win/lose count 3.0/3.0 (0.0)
# Epoch 055/100 | Loss 0.0035 | Win/lose count 10.0/5.0 (5.0)
# Epoch 056/100 | Loss 0.0004 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 057/100 | Loss 0.0020 | Win/lose count 4.5/2.0 (2.5)
# Epoch 058/100 | Loss 0.0015 | Win/lose count 10.0/5.0 (5.0)
# Epoch 059/100 | Loss 0.0010 | Win/lose count 4.0/1.0 (3.0)
# Epoch 060/100 | Loss 0.0043 | Win/lose count 3.5/3.0 (0.5)
# Epoch 061/100 | Loss 0.0012 | Win/lose count 6.0/3.0 (3.0)
# Epoch 062/100 | Loss 0.0027 | Win/lose count 4.0/4.0 (0.0)
# Epoch 063/100 | Loss 0.0010 | Win/lose count 10.0/5.0 (5.0)
# Epoch 064/100 | Loss 0.0027 | Win/lose count 2.5/0 (2.5)
# Epoch 065/100 | Loss 0.0083 | Win/lose count 3.5/2.0 (1.5)
# Epoch 066/100 | Loss 0.0009 | Win/lose count 4.5/0 (4.5)
# Epoch 067/100 | Loss 0.0008 | Win/lose count 7.5/6.0 (1.5)
# Epoch 068/100 | Loss 0.0068 | Win/lose count 1.5/9.0 (-7.5)
# Epoch 069/100 | Loss 0.0034 | Win/lose count 4.0/2.0 (2.0)
# Epoch 070/100 | Loss 0.0040 | Win/lose count 8.0/4.0 (4.0)
# Epoch 071/100 | Loss 0.0005 | Win/lose count 6.0/5.0 (1.0)
# Epoch 072/100 | Loss 0.0002 | Win/lose count 5.5/0 (5.5)
# Epoch 073/100 | Loss 0.0015 | Win/lose count 4.0/1.0 (3.0)
# Epoch 074/100 | Loss 0.0008 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 075/100 | Loss 0.0007 | Win/lose count 8.5/4.0 (4.5)
# Epoch 076/100 | Loss 0.0019 | Win/lose count 5.0/3.0 (2.0)
# Epoch 077/100 | Loss 0.0039 | Win/lose count 3.0/0 (3.0)
# Epoch 078/100 | Loss 0.0003 | Win/lose count 5.0/1.0 (4.0)
# Epoch 079/100 | Loss 0.0026 | Win/lose count 2.0/1.0 (1.0)
# Epoch 080/100 | Loss 0.0011 | Win/lose count 8.0/4.0 (4.0)
# Epoch 081/100 | Loss 0.0061 | Win/lose count 8.5/1.0 (7.5)
# Epoch 082/100 | Loss 0.0833 | Win/lose count 5.0/2.0 (3.0)
# Epoch 083/100 | Loss 0.0005 | Win/lose count 3.5/1.0 (2.5)
# Epoch 084/100 | Loss 0.0015 | Win/lose count 8.0/3.0 (5.0)
# Epoch 085/100 | Loss 0.0007 | Win/lose count 8.0/3.0 (5.0)
# Epoch 086/100 | Loss 0.0014 | Win/lose count 3.5/3.0 (0.5)
# Epoch 087/100 | Loss 0.0010 | Win/lose count 1.5/1.0 (0.5)
# Epoch 088/100 | Loss 0.0869 | Win/lose count 13.0/4.0 (9.0)
# Epoch 089/100 | Loss 0.0031 | Win/lose count 5.5/2.0 (3.5)
# Epoch 090/100 | Loss 0.0011 | Win/lose count 1.0/1.0 (0.0)
# Epoch 091/100 | Loss 0.0044 | Win/lose count 8.0/4.0 (4.0)
# Epoch 092/100 | Loss 0.0013 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 093/100 | Loss 0.0904 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 094/100 | Loss 0.0021 | Win/lose count 6.0/2.0 (4.0)
# Epoch 095/100 | Loss 0.0004 | Win/lose count 3.5/0 (3.5)
# Epoch 096/100 | Loss 0.0027 | Win/lose count 4.5/2.0 (2.5)
# Epoch 097/100 | Loss 0.0018 | Win/lose count 4.0/2.0 (2.0)
# Epoch 098/100 | Loss 0.0015 | Win/lose count 7.5/2.0 (5.5)
# Epoch 099/100 | Loss 0.0047 | Win/lose count 5.0/0 (5.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# __Tunning hyperparameters (test all combine): __
#
# - *Epsilon* 0.1 optimal (test for 0.5 and 0.05)
# - *Learning* rate 0.1 optimal (test for 0.5 and 0.05)
# - *Memory* : should no be too small (if too small, stationnarity not happen)
# - *Batch_size* : 16, decrease loss
# - *Archictecture* : width and depth decrease performance

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__( *args,**kwargs)
        
        model = Sequential()
        #Best model
        model.add(Conv2D(32,(2,2),input_shape=(5,5,self.n_state,),activation='relu'))
        model.add(Conv2D(64,(2,2),activation='relu'))
        model.add(Flatten())
        model.add(Dense(4))
        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=0.1, epsilon = 0.1, memory_size=2000, batch_size = 16)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train40.mp4'))
# Out:
# Epoch 000/100 | Loss 0.0176 | Win/lose count 6.0/7.0 (-1.0)
# Epoch 001/100 | Loss 0.0163 | Win/lose count 3.0/1.0 (2.0)
# Epoch 002/100 | Loss 0.0036 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 003/100 | Loss 0.0017 | Win/lose count 4.0/4.0 (0.0)
# Epoch 004/100 | Loss 0.0917 | Win/lose count 2.5/1.0 (1.5)
# Epoch 005/100 | Loss 0.0011 | Win/lose count 1.0/1.0 (0.0)
# Epoch 006/100 | Loss 0.0022 | Win/lose count 3.0/2.0 (1.0)
# Epoch 007/100 | Loss 0.0010 | Win/lose count 6.0/1.0 (5.0)
# Epoch 008/100 | Loss 0.0125 | Win/lose count 9.0/1.0 (8.0)
# Epoch 009/100 | Loss 0.0032 | Win/lose count 6.0/0 (6.0)
# Epoch 010/100 | Loss 0.0017 | Win/lose count 5.5/1.0 (4.5)
# Epoch 011/100 | Loss 0.0017 | Win/lose count 4.5/1.0 (3.5)
# Epoch 012/100 | Loss 0.0013 | Win/lose count 10.5/1.0 (9.5)
# Epoch 013/100 | Loss 0.0066 | Win/lose count 6.5/1.0 (5.5)
# Epoch 014/100 | Loss 0.0007 | Win/lose count 7.0/2.0 (5.0)
# Epoch 015/100 | Loss 0.0044 | Win/lose count 11.0/2.0 (9.0)
# Epoch 016/100 | Loss 0.0016 | Win/lose count 10.0/4.0 (6.0)
# Epoch 017/100 | Loss 0.0003 | Win/lose count 12.0/4.0 (8.0)
# Epoch 018/100 | Loss 0.0006 | Win/lose count 10.5/1.0 (9.5)
# Epoch 019/100 | Loss 0.0010 | Win/lose count 10.5/6.0 (4.5)
# Epoch 020/100 | Loss 0.0010 | Win/lose count 11.0/3.0 (8.0)
# Epoch 021/100 | Loss 0.0013 | Win/lose count 9.0/2.0 (7.0)
# Epoch 022/100 | Loss 0.0040 | Win/lose count 15.0/1.0 (14.0)
# Epoch 023/100 | Loss 0.0014 | Win/lose count 10.0/2.0 (8.0)
# Epoch 024/100 | Loss 0.0034 | Win/lose count 3.0/3.0 (0.0)
# Epoch 025/100 | Loss 0.0005 | Win/lose count 3.5/1.0 (2.5)
# Epoch 026/100 | Loss 0.0006 | Win/lose count 14.0/0 (14.0)
# Epoch 027/100 | Loss 0.0008 | Win/lose count 10.0/1.0 (9.0)
# Epoch 028/100 | Loss 0.0020 | Win/lose count 5.5/4.0 (1.5)
# Epoch 029/100 | Loss 0.0014 | Win/lose count 10.5/4.0 (6.5)
# Epoch 030/100 | Loss 0.0004 | Win/lose count 9.5/4.0 (5.5)
# Epoch 031/100 | Loss 0.0016 | Win/lose count 4.5/2.0 (2.5)
# Epoch 032/100 | Loss 0.0010 | Win/lose count 14.0/3.0 (11.0)
# Epoch 033/100 | Loss 0.0017 | Win/lose count 10.0/4.0 (6.0)
# Epoch 034/100 | Loss 0.0015 | Win/lose count 4.0/0 (4.0)
# Epoch 035/100 | Loss 0.0010 | Win/lose count 6.5/2.0 (4.5)
# Epoch 036/100 | Loss 0.0016 | Win/lose count 7.5/2.0 (5.5)
# Epoch 037/100 | Loss 0.0006 | Win/lose count 17.5/0 (17.5)
# Epoch 038/100 | Loss 0.0009 | Win/lose count 9.5/0 (9.5)
# Epoch 039/100 | Loss 0.0016 | Win/lose count 9.0/1.0 (8.0)
# Epoch 040/100 | Loss 0.0006 | Win/lose count 13.5/1.0 (12.5)
# Epoch 041/100 | Loss 0.0004 | Win/lose count 11.5/2.0 (9.5)
# Epoch 042/100 | Loss 0.0005 | Win/lose count 9.0/1.0 (8.0)
# Epoch 043/100 | Loss 0.0007 | Win/lose count 6.5/2.0 (4.5)
# Epoch 044/100 | Loss 0.0011 | Win/lose count 12.0/3.0 (9.0)
# Epoch 045/100 | Loss 0.0010 | Win/lose count 11.0/2.0 (9.0)
# Epoch 046/100 | Loss 0.0128 | Win/lose count 11.0/2.0 (9.0)
# Epoch 047/100 | Loss 0.0010 | Win/lose count 11.0/2.0 (9.0)
# Epoch 048/100 | Loss 0.0008 | Win/lose count 12.0/6.0 (6.0)
# Epoch 049/100 | Loss 0.0029 | Win/lose count 10.0/0 (10.0)
# Epoch 050/100 | Loss 0.0011 | Win/lose count 10.0/1.0 (9.0)
# Epoch 051/100 | Loss 0.0020 | Win/lose count 17.5/2.0 (15.5)
# Epoch 052/100 | Loss 0.0001 | Win/lose count 4.0/2.0 (2.0)
# Epoch 053/100 | Loss 0.0016 | Win/lose count 8.0/0 (8.0)
# Epoch 054/100 | Loss 0.0007 | Win/lose count 11.0/4.0 (7.0)
# Epoch 055/100 | Loss 0.0018 | Win/lose count 12.0/3.0 (9.0)
# Epoch 056/100 | Loss 0.0002 | Win/lose count 6.5/2.0 (4.5)
# Epoch 057/100 | Loss 0.0016 | Win/lose count 2.5/1.0 (1.5)
# Epoch 058/100 | Loss 0.0008 | Win/lose count 10.0/0 (10.0)
# Epoch 059/100 | Loss 0.0003 | Win/lose count 4.5/4.0 (0.5)
# Epoch 060/100 | Loss 0.0005 | Win/lose count 3.0/0 (3.0)
# Epoch 061/100 | Loss 0.0012 | Win/lose count 5.0/1.0 (4.0)
# Epoch 062/100 | Loss 0.0031 | Win/lose count 14.5/1.0 (13.5)
# Epoch 063/100 | Loss 0.0015 | Win/lose count 10.0/0 (10.0)
# Epoch 064/100 | Loss 0.0039 | Win/lose count 3.5/1.0 (2.5)
# Epoch 065/100 | Loss 0.0004 | Win/lose count 7.0/3.0 (4.0)
# Epoch 066/100 | Loss 0.0012 | Win/lose count 15.0/2.0 (13.0)
# Epoch 067/100 | Loss 0.0006 | Win/lose count 3.5/0 (3.5)
# Epoch 068/100 | Loss 0.0008 | Win/lose count 8.5/0 (8.5)
# Epoch 069/100 | Loss 0.0007 | Win/lose count 12.5/6.0 (6.5)
# Epoch 070/100 | Loss 0.0024 | Win/lose count 11.5/1.0 (10.5)
# Epoch 071/100 | Loss 0.0011 | Win/lose count 1.5/1.0 (0.5)
# Epoch 072/100 | Loss 0.0010 | Win/lose count 7.0/4.0 (3.0)
# Epoch 073/100 | Loss 0.0003 | Win/lose count 14.5/1.0 (13.5)
# Epoch 074/100 | Loss 0.0004 | Win/lose count 8.0/0 (8.0)
# Epoch 075/100 | Loss 0.0002 | Win/lose count 11.5/2.0 (9.5)
# Epoch 076/100 | Loss 0.0028 | Win/lose count 5.0/3.0 (2.0)
# Epoch 077/100 | Loss 0.0011 | Win/lose count 11.5/4.0 (7.5)
# Epoch 078/100 | Loss 0.0024 | Win/lose count 12.5/0 (12.5)
# Epoch 079/100 | Loss 0.0008 | Win/lose count 7.0/3.0 (4.0)
# Epoch 080/100 | Loss 0.0004 | Win/lose count 4.5/0 (4.5)
# Epoch 081/100 | Loss 0.0011 | Win/lose count 6.0/3.0 (3.0)
# Epoch 082/100 | Loss 0.0020 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 083/100 | Loss 0.0008 | Win/lose count 6.5/0 (6.5)
# Epoch 084/100 | Loss 0.0015 | Win/lose count 10.5/2.0 (8.5)
# Epoch 085/100 | Loss 0.0006 | Win/lose count 11.5/3.0 (8.5)
# Epoch 086/100 | Loss 0.0006 | Win/lose count 21.0/3.0 (18.0)
# Epoch 087/100 | Loss 0.0012 | Win/lose count 7.5/4.0 (3.5)
# Epoch 088/100 | Loss 0.0006 | Win/lose count 10.5/2.0 (8.5)
# Epoch 089/100 | Loss 0.0013 | Win/lose count 6.5/5.0 (1.5)
# Epoch 090/100 | Loss 0.0012 | Win/lose count 8.5/5.0 (3.5)
# Epoch 091/100 | Loss 0.0004 | Win/lose count 4.5/2.0 (2.5)
# Epoch 092/100 | Loss 0.0005 | Win/lose count 12.0/1.0 (11.0)
# Epoch 093/100 | Loss 0.0010 | Win/lose count 12.0/4.0 (8.0)
# Epoch 094/100 | Loss 0.0002 | Win/lose count 2.0/1.0 (1.0)
# Epoch 095/100 | Loss 0.0006 | Win/lose count 11.0/0 (11.0)
# Epoch 096/100 | Loss 0.0005 | Win/lose count 7.0/5.0 (2.0)
# Epoch 097/100 | Loss 0.0008 | Win/lose count 9.5/3.0 (6.5)
# Epoch 098/100 | Loss 0.1201 | Win/lose count 7.0/4.0 (3.0)
# Epoch 099/100 | Loss 0.0025 | Win/lose count 8.5/5.0 (3.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# __Tunning hyperparameters (test all combine): __
#
# - *Epsilon* 0.1 optimal (test for 0.5 and 0.05)
# - *Learning* rate 0.1 optimal (test for 0.5 and 0.05)
# - *Memory* : should no be too small (if too small, stationnarity not happen)
# - *Batch_size* : 16, decrease loss
# - *Archictecture* : best model : 2 CNN, 1 Dense, relu

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.9)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN
# Win/lose count 19.0/2.0. Average score (17.0)
# Win/lose count 15.0/2.0. Average score (15.0)
# Win/lose count 18.5/1.0. Average score (15.833333333333334)
# Win/lose count 6.5/0. Average score (13.5)
# Win/lose count 16.5/1.0. Average score (13.9)
# Win/lose count 13.5/1.0. Average score (13.666666666666666)
# Win/lose count 10.0/0. Average score (13.142857142857142)
# Win/lose count 16.0/4.0. Average score (13.0)
# Win/lose count 22.5/4.0. Average score (13.61111111111111)
# Win/lose count 13.0/1.0. Average score (13.45)
# Win/lose count 11.5/1.0. Average score (13.181818181818182)
# Win/lose count 19.0/2.0. Average score (13.5)
# Win/lose count 16.0/2.0. Average score (13.538461538461538)
# Win/lose count 26.0/1.0. Average score (14.357142857142858)
# Win/lose count 11.0/1.0. Average score (14.066666666666666)
# Win/lose count 23.5/0. Average score (14.65625)
# Win/lose count 9.5/0. Average score (14.352941176470589)
# Win/lose count 31.5/1.0. Average score (15.25)
# Win/lose count 5.0/1.0. Average score (14.657894736842104)
# Win/lose count 14.5/1.0. Average score (14.6)
# Win/lose count 15.5/0. Average score (14.642857142857142)
# Win/lose count 16.5/2.0. Average score (14.636363636363637)
# Win/lose count 10.5/0. Average score (14.456521739130435)
# Win/lose count 9.0/0. Average score (14.229166666666666)
# Win/lose count 20.0/2.0. Average score (14.38)
# Win/lose count 19.0/2.0. Average score (14.48076923076923)
# Win/lose count 18.0/1.0. Average score (14.574074074074074)
# Win/lose count 22.5/3.0. Average score (14.75)
# Win/lose count 17.0/2.0. Average score (14.758620689655173)
# Win/lose count 14.0/2.0. Average score (14.666666666666666)
# Win/lose count 6.5/1.0. Average score (14.370967741935484)
# Win/lose count 19.0/0. Average score (14.515625)
# Win/lose count 10.5/0. Average score (14.393939393939394)
# Win/lose count 6.0/0. Average score (14.147058823529411)
# Win/lose count 7.5/1.0. Average score (13.928571428571429)
# Win/lose count 13.0/2.0. Average score (13.847222222222221)
# Win/lose count 17.5/1.0. Average score (13.91891891891892)
# Win/lose count 8.0/4.0. Average score (13.657894736842104)
# Win/lose count 8.5/2.0. Average score (13.474358974358974)
# Win/lose count 25.5/0. Average score (13.775)
# Win/lose count 24.5/1.0. Average score (14.012195121951219)
# Win/lose count 11.5/1.0. Average score (13.928571428571429)
# Win/lose count 25.0/2.0. Average score (14.13953488372093)
# Win/lose count 4.0/1.0. Average score (13.886363636363637)
# Win/lose count 17.5/1.0. Average score (13.944444444444445)
# Win/lose count 18.5/1.0. Average score (14.021739130434783)
# Win/lose count 11.5/0. Average score (13.96808510638298)
# Win/lose count 9.0/3.0. Average score (13.802083333333334)
# Win/lose count 25.5/1.0. Average score (14.020408163265307)
# Win/lose count 17.5/3.0. Average score (14.03)
# Final score: 14.03
# Test of the FC
# Win/lose count 7.0/1.0. Average score (6.0)
# Win/lose count 9.0/2.0. Average score (6.5)
# Win/lose count 7.5/1.0. Average score (6.5)
# Win/lose count 8.5/1.0. Average score (6.75)
# Win/lose count 5.5/1.0. Average score (6.3)
# Win/lose count 7.0/0. Average score (6.416666666666667)
# Win/lose count 6.5/2.0. Average score (6.142857142857143)
# Win/lose count 5.0/1.0. Average score (5.875)
# Win/lose count 7.0/1.0. Average score (5.888888888888889)
# Win/lose count 9.0/1.0. Average score (6.1)
# Win/lose count 5.0/0. Average score (6.0)
# Win/lose count 9.5/1.0. Average score (6.208333333333333)
# Win/lose count 9.5/4.0. Average score (6.153846153846154)
# Win/lose count 5.5/2.0. Average score (5.964285714285714)
# Win/lose count 11.0/2.0. Average score (6.166666666666667)
# Win/lose count 7.0/4.0. Average score (5.96875)
# Win/lose count 2.0/0. Average score (5.735294117647059)
# Win/lose count 4.0/1.0. Average score (5.583333333333333)
# Win/lose count 6.0/2.0. Average score (5.5)
# Win/lose count 5.5/1.0. Average score (5.45)
# Win/lose count 4.0/1.0. Average score (5.333333333333333)
# Win/lose count 2.5/2.0. Average score (5.113636363636363)
# Win/lose count 7.0/2.0. Average score (5.108695652173913)
# Win/lose count 8.0/1.0. Average score (5.1875)
# Win/lose count 6.5/5.0. Average score (5.04)
# Win/lose count 7.0/1.0. Average score (5.076923076923077)
# Win/lose count 7.0/0. Average score (5.148148148148148)
# Win/lose count 5.0/2.0. Average score (5.071428571428571)
# Win/lose count 8.5/1.0. Average score (5.155172413793103)
# Win/lose count 5.0/1.0. Average score (5.116666666666666)
# Win/lose count 7.0/0. Average score (5.17741935483871)
# Win/lose count 6.0/1.0. Average score (5.171875)
# Win/lose count 8.0/2.0. Average score (5.196969696969697)
# Win/lose count 3.5/3.0. Average score (5.0588235294117645)
# Win/lose count 5.5/2.0. Average score (5.014285714285714)
# Win/lose count 7.0/1.0. Average score (5.041666666666667)
# Win/lose count 8.5/1.0. Average score (5.108108108108108)
# Win/lose count 8.0/2.0. Average score (5.131578947368421)
# Win/lose count 8.5/2.0. Average score (5.166666666666667)
# Win/lose count 8.0/2.0. Average score (5.1875)
# Win/lose count 10.0/3.0. Average score (5.2317073170731705)
# Win/lose count 4.5/1.0. Average score (5.190476190476191)
# Win/lose count 5.0/1.0. Average score (5.162790697674419)
# Win/lose count 8.0/2.0. Average score (5.181818181818182)
# Win/lose count 5.5/1.0. Average score (5.166666666666667)
# Win/lose count 8.5/1.0. Average score (5.217391304347826)
# Win/lose count 3.0/1.0. Average score (5.148936170212766)
# Win/lose count 7.0/1.0. Average score (5.166666666666667)
# Win/lose count 12.5/0. Average score (5.316326530612245)
# Win/lose count 5.0/1.0. Average score (5.29)
# Final score: 5.29

# %%
HTML(display_videos('cnn_test9.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test9.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# Temperature increase the density of reward pixel. So of course, finally, it increase the results.
#
#
# We observe that the rat do not explore the game and tends to be stuck and oscillate between 2 positions.

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,epsilon=0.1, decay=0.99, prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0
        
        agent.set_epsilon(epsilon)

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            agent.epsilon *= decay
            
            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action, train=True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward
                
            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))
        
        #NEW
        self.malus_position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action, train=False):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[:, -2:] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        
        #new
        reward = 0
        if train:
            reward = -self.malus_position[self.x, self.y]
        self.malus_position[self.x, self.y] += 0.1
        reward = reward + self.board[self.x, self.y]   
        
        
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time 
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]

        
        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0 
        
        self.board = bonus + malus 
        
        self.board[:2,:] = 0
        self.board[-2:,:] = 0
        self.board[:, :2] = 0
        self.board[:, -2:] = 0

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1 # error, 2 times same line
        self.position[:, -2:] = -1
        self.board[self.x,self.y] = 0
        self.t = 0
        
        self.malus_position = np.zeros((self.grid_size, self.grid_size))

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore40.mp4'))
# Out:
# Epoch 000/100 | Loss 0.0256 | Win/lose count 15.0/45.00000000000002 (-30.00000000000002)
# Epoch 001/100 | Loss 0.0222 | Win/lose count 24.5/28.60000000000002 (-4.100000000000019)
# Epoch 002/100 | Loss 0.0269 | Win/lose count 18.5/46.7 (-28.200000000000003)
# Epoch 003/100 | Loss 0.0185 | Win/lose count 17.0/24.00000000000003 (-7.000000000000028)
# Epoch 004/100 | Loss 0.0125 | Win/lose count 23.5/14.899999999999975 (8.600000000000025)
# Epoch 005/100 | Loss 0.0154 | Win/lose count 17.5/13.699999999999982 (3.8000000000000185)
# Epoch 006/100 | Loss 0.0086 | Win/lose count 24.5/13.39999999999999 (11.10000000000001)
# Epoch 007/100 | Loss 0.0369 | Win/lose count 28.0/10.99999999999999 (17.00000000000001)
# Epoch 008/100 | Loss 0.0128 | Win/lose count 22.0/11.999999999999984 (10.000000000000016)
# Epoch 009/100 | Loss 0.0158 | Win/lose count 25.0/12.69999999999998 (12.30000000000002)
# Epoch 010/100 | Loss 0.0077 | Win/lose count 24.0/13.799999999999983 (10.200000000000017)
# Epoch 011/100 | Loss 0.0101 | Win/lose count 25.0/13.999999999999982 (11.000000000000018)
# Epoch 012/100 | Loss 0.0444 | Win/lose count 27.0/12.399999999999984 (14.600000000000016)
# Epoch 013/100 | Loss 0.0337 | Win/lose count 25.5/13.199999999999987 (12.300000000000013)
# Epoch 014/100 | Loss 0.0111 | Win/lose count 28.0/15.99999999999999 (12.00000000000001)
# Epoch 015/100 | Loss 0.0070 | Win/lose count 26.5/13.499999999999986 (13.000000000000014)
# Epoch 016/100 | Loss 0.0094 | Win/lose count 19.5/16.29999999999998 (3.2000000000000206)
# Epoch 017/100 | Loss 0.0230 | Win/lose count 24.5/14.199999999999985 (10.300000000000015)
# Epoch 018/100 | Loss 0.0421 | Win/lose count 24.0/10.799999999999986 (13.200000000000014)
# Epoch 019/100 | Loss 0.0064 | Win/lose count 24.5/16.699999999999985 (7.800000000000015)
# Epoch 020/100 | Loss 0.0125 | Win/lose count 23.5/15.199999999999985 (8.300000000000015)
# Epoch 021/100 | Loss 0.0087 | Win/lose count 26.5/15.099999999999985 (11.400000000000015)
# Epoch 022/100 | Loss 0.0075 | Win/lose count 21.5/16.899999999999977 (4.600000000000023)
# Epoch 023/100 | Loss 0.0095 | Win/lose count 28.5/12.199999999999982 (16.30000000000002)
# Epoch 024/100 | Loss 0.0067 | Win/lose count 24.5/19.700000000000003 (4.799999999999997)
# Epoch 025/100 | Loss 0.0060 | Win/lose count 22.5/17.69999999999998 (4.8000000000000185)
# Epoch 026/100 | Loss 0.0106 | Win/lose count 25.0/44.49999999999999 (-19.499999999999993)
# Epoch 027/100 | Loss 0.0057 | Win/lose count 19.5/18.599999999999998 (0.9000000000000021)
# Epoch 028/100 | Loss 0.0058 | Win/lose count 27.5/10.699999999999987 (16.80000000000001)
# Epoch 029/100 | Loss 0.0084 | Win/lose count 24.0/15.39999999999998 (8.60000000000002)
# Epoch 030/100 | Loss 0.0041 | Win/lose count 17.5/27.50000000000001 (-10.00000000000001)
# Epoch 031/100 | Loss 0.0043 | Win/lose count 21.0/14.899999999999979 (6.100000000000021)
# Epoch 032/100 | Loss 0.0041 | Win/lose count 27.0/12.09999999999998 (14.90000000000002)
# Epoch 033/100 | Loss 0.0077 | Win/lose count 22.5/14.79999999999998 (7.700000000000021)
# Epoch 034/100 | Loss 0.0033 | Win/lose count 24.5/12.799999999999983 (11.700000000000017)
# Epoch 035/100 | Loss 0.0035 | Win/lose count 20.5/12.699999999999987 (7.800000000000013)
# Epoch 036/100 | Loss 0.0038 | Win/lose count 30.0/10.199999999999987 (19.80000000000001)
# Epoch 037/100 | Loss 0.0046 | Win/lose count 15.5/20.000000000000018 (-4.500000000000018)
# Epoch 038/100 | Loss 0.0365 | Win/lose count 22.5/12.99999999999999 (9.50000000000001)
# Epoch 039/100 | Loss 0.0035 | Win/lose count 24.0/17.699999999999992 (6.300000000000008)
# Epoch 040/100 | Loss 0.0064 | Win/lose count 22.5/15.199999999999983 (7.300000000000017)
# Epoch 041/100 | Loss 0.0072 | Win/lose count 26.5/13.999999999999982 (12.500000000000018)
# Epoch 042/100 | Loss 0.0046 | Win/lose count 20.0/86.70000000000002 (-66.70000000000002)
# Epoch 043/100 | Loss 0.0054 | Win/lose count 25.5/11.89999999999998 (13.60000000000002)
# Epoch 044/100 | Loss 0.0034 | Win/lose count 20.5/11.299999999999983 (9.200000000000017)
# Epoch 045/100 | Loss 0.0041 | Win/lose count 19.5/12.899999999999986 (6.600000000000014)
# Epoch 046/100 | Loss 0.0053 | Win/lose count 24.5/20.099999999999977 (4.4000000000000234)
# Epoch 047/100 | Loss 0.0070 | Win/lose count 22.0/11.599999999999989 (10.400000000000011)
# Epoch 048/100 | Loss 0.0315 | Win/lose count 27.0/12.699999999999985 (14.300000000000015)
# Epoch 049/100 | Loss 0.0050 | Win/lose count 24.5/13.599999999999985 (10.900000000000015)
# Epoch 050/100 | Loss 0.0067 | Win/lose count 24.5/15.599999999999975 (8.900000000000025)
# Epoch 051/100 | Loss 0.0065 | Win/lose count 23.5/12.699999999999989 (10.800000000000011)
# Epoch 052/100 | Loss 0.0254 | Win/lose count 17.0/25.700000000000006 (-8.700000000000006)
# Epoch 053/100 | Loss 0.0087 | Win/lose count 25.0/18.5 (6.5)
# Epoch 054/100 | Loss 0.0040 | Win/lose count 26.0/13.799999999999976 (12.200000000000024)
# Epoch 055/100 | Loss 0.0024 | Win/lose count 27.0/13.799999999999992 (13.200000000000008)
# Epoch 056/100 | Loss 0.0503 | Win/lose count 23.0/14.799999999999985 (8.200000000000015)
# Epoch 057/100 | Loss 0.0032 | Win/lose count 12.0/72.19999999999995 (-60.199999999999946)
# Epoch 058/100 | Loss 0.0038 | Win/lose count 19.5/23.09999999999998 (-3.59999999999998)
# Epoch 059/100 | Loss 0.0256 | Win/lose count 23.5/17.099999999999984 (6.400000000000016)
# Epoch 060/100 | Loss 0.0039 | Win/lose count 23.0/18.099999999999984 (4.900000000000016)
# Epoch 061/100 | Loss 0.0127 | Win/lose count 22.0/16.69999999999999 (5.300000000000011)
# Epoch 062/100 | Loss 0.0040 | Win/lose count 19.0/17.399999999999995 (1.600000000000005)
# Epoch 063/100 | Loss 0.0099 | Win/lose count 22.5/13.999999999999975 (8.500000000000025)
# Epoch 064/100 | Loss 0.0033 | Win/lose count 25.5/14.099999999999987 (11.400000000000013)
# Epoch 065/100 | Loss 0.0036 | Win/lose count 20.5/27.099999999999987 (-6.599999999999987)
# Epoch 066/100 | Loss 0.0040 | Win/lose count 32.0/13.299999999999992 (18.70000000000001)
# Epoch 067/100 | Loss 0.0043 | Win/lose count 26.5/15.599999999999978 (10.900000000000022)
# Epoch 068/100 | Loss 0.0040 | Win/lose count 24.0/11.49999999999999 (12.50000000000001)
# Epoch 069/100 | Loss 0.0096 | Win/lose count 19.5/29.80000000000002 (-10.300000000000018)
# Epoch 070/100 | Loss 0.0094 | Win/lose count 17.5/26.499999999999996 (-8.999999999999996)
# Epoch 071/100 | Loss 0.0038 | Win/lose count 25.0/15.799999999999981 (9.200000000000019)
# Epoch 072/100 | Loss 0.0225 | Win/lose count 21.5/15.79999999999998 (5.700000000000021)
# Epoch 073/100 | Loss 0.0341 | Win/lose count 21.5/13.599999999999985 (7.900000000000015)
# Epoch 074/100 | Loss 0.0049 | Win/lose count 20.5/14.099999999999987 (6.400000000000013)
# Epoch 075/100 | Loss 0.0043 | Win/lose count 27.5/12.599999999999982 (14.900000000000018)
# Epoch 076/100 | Loss 0.0047 | Win/lose count 20.5/16.499999999999982 (4.000000000000018)
# Epoch 077/100 | Loss 0.0032 | Win/lose count 26.5/13.999999999999986 (12.500000000000014)
# Epoch 078/100 | Loss 0.0032 | Win/lose count 24.5/13.899999999999983 (10.600000000000017)
# Epoch 079/100 | Loss 0.0289 | Win/lose count 23.0/17.799999999999994 (5.200000000000006)
# Epoch 080/100 | Loss 0.0023 | Win/lose count 16.5/18.499999999999996 (-1.9999999999999964)
# Epoch 081/100 | Loss 0.0039 | Win/lose count 23.5/10.89999999999999 (12.60000000000001)
# Epoch 082/100 | Loss 0.0023 | Win/lose count 26.0/12.699999999999989 (13.300000000000011)
# Epoch 083/100 | Loss 0.0192 | Win/lose count 25.5/18.7 (6.800000000000001)
# Epoch 084/100 | Loss 0.0019 | Win/lose count 19.5/17.699999999999996 (1.8000000000000043)
# Epoch 085/100 | Loss 0.0043 | Win/lose count 17.5/22.900000000000002 (-5.400000000000002)
# Epoch 086/100 | Loss 0.0027 | Win/lose count 14.5/65.19999999999999 (-50.69999999999999)
# Epoch 087/100 | Loss 0.0025 | Win/lose count 22.5/11.299999999999985 (11.200000000000015)
# Epoch 088/100 | Loss 0.0024 | Win/lose count 21.0/12.499999999999979 (8.500000000000021)
# Epoch 089/100 | Loss 0.0205 | Win/lose count 26.5/15.899999999999983 (10.600000000000017)
# Epoch 090/100 | Loss 0.0032 | Win/lose count 25.0/11.999999999999984 (13.000000000000016)
# Epoch 091/100 | Loss 0.0022 | Win/lose count 23.0/12.299999999999983 (10.700000000000017)
# Epoch 092/100 | Loss 0.0265 | Win/lose count 18.0/22.799999999999986 (-4.7999999999999865)
# Epoch 093/100 | Loss 0.0049 | Win/lose count 18.0/18.09999999999999 (-0.09999999999999076)
# Epoch 094/100 | Loss 0.0332 | Win/lose count 21.5/11.099999999999987 (10.400000000000013)
# Epoch 095/100 | Loss 0.0037 | Win/lose count 24.5/23.699999999999996 (0.8000000000000043)
# Epoch 096/100 | Loss 0.0035 | Win/lose count 20.5/18.69999999999998 (1.8000000000000185)
# Epoch 097/100 | Loss 0.0051 | Win/lose count 23.5/20.90000000000002 (2.59999999999998)
# Epoch 098/100 | Loss 0.0031 | Win/lose count 19.5/13.599999999999987 (5.900000000000013)
# Epoch 099/100 | Loss 0.0063 | Win/lose count 23.5/10.299999999999985 (13.200000000000015)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore4.mp4'))
# Out:
# Win/lose count 24.0/1.0. Average score (23.0)
# Win/lose count 19.5/1.0. Average score (20.75)
# Win/lose count 29.0/1.0. Average score (23.166666666666668)
# Win/lose count 26.0/1.0. Average score (23.625)
# Win/lose count 28.5/0. Average score (24.6)
# Win/lose count 20.0/4.0. Average score (23.166666666666668)
# Win/lose count 17.0/3.0. Average score (21.857142857142858)
# Win/lose count 28.5/3.0. Average score (22.3125)
# Win/lose count 28.0/2.0. Average score (22.72222222222222)
# Win/lose count 23.0/1.0. Average score (22.65)
# Win/lose count 28.5/2.0. Average score (23.0)
# Win/lose count 24.0/1.0. Average score (23.0)
# Win/lose count 22.5/2.0. Average score (22.807692307692307)
# Win/lose count 19.0/3.0. Average score (22.321428571428573)
# Win/lose count 24.0/2.0. Average score (22.3)
# Win/lose count 23.5/3.0. Average score (22.1875)
# Win/lose count 20.0/2.0. Average score (21.941176470588236)
# Win/lose count 21.0/0. Average score (21.88888888888889)
# Win/lose count 28.5/2.0. Average score (22.13157894736842)
# Win/lose count 24.5/3.0. Average score (22.1)
# Win/lose count 22.0/2.0. Average score (22.0)
# Win/lose count 26.5/2.0. Average score (22.113636363636363)
# Win/lose count 21.5/0. Average score (22.08695652173913)
# Win/lose count 22.5/2.0. Average score (22.020833333333332)
# Win/lose count 21.5/1.0. Average score (21.96)
# Win/lose count 22.5/2.0. Average score (21.903846153846153)
# Win/lose count 26.5/0. Average score (22.074074074074073)
# Win/lose count 28.5/0. Average score (22.303571428571427)
# Win/lose count 25.5/2.0. Average score (22.344827586206897)
# Win/lose count 24.5/1.0. Average score (22.383333333333333)
# Win/lose count 24.5/0. Average score (22.451612903225808)
# Win/lose count 27.0/1.0. Average score (22.5625)
# Win/lose count 25.5/0. Average score (22.651515151515152)
# Win/lose count 21.5/2.0. Average score (22.558823529411764)
# Win/lose count 17.0/1.0. Average score (22.37142857142857)
# Win/lose count 21.5/1.0. Average score (22.319444444444443)
# Win/lose count 19.5/0. Average score (22.243243243243242)
# Win/lose count 25.5/3.0. Average score (22.25)
# Win/lose count 17.0/1.0. Average score (22.08974358974359)
# Win/lose count 21.0/2.0. Average score (22.0125)
# Win/lose count 19.0/1.0. Average score (21.914634146341463)
# Win/lose count 20.0/0. Average score (21.86904761904762)
# Win/lose count 24.5/1.0. Average score (21.906976744186046)
# Win/lose count 22.5/1.0. Average score (21.897727272727273)
# Win/lose count 26.0/1.0. Average score (21.966666666666665)
# Win/lose count 21.5/2.0. Average score (21.91304347826087)
# Win/lose count 30.5/1.0. Average score (22.074468085106382)
# Win/lose count 19.0/4.0. Average score (21.927083333333332)
# Win/lose count 25.5/2.0. Average score (21.959183673469386)
# Win/lose count 27.0/4.0. Average score (21.98)
# Final score: 21.98
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %%
class Mimic(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(Mimic, self).__init__(epsilon = epsilon)
        self.discount = 0.99
        self.grid_size = grid_size
        self.n_state = n_state
        self.memory = Memory(memory_size)
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(s.reshape([1,s.shape[0],s.shape[1],s.shape[2]]))[0,:])

    def reinforce(self, s_, a_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_[:,:,1:], a_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            ######## FILL IN
            
            #new
            s_, a_  = self.memory.random_access()
            
            target_q[i, a_] = 5
            input_states[i] = s_
            

        l = self.model.train_on_batch(input_states, target_q)


        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model
        

        
class CNN_Mimic(Mimic):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(CNN_Mimic, self).__init__(*args,**kwargs)
        
        model = Sequential()
        model.add(Conv2D(50,(2,2),input_shape=(5,5,self.n_state,),activation='relu'))
        model.add(Flatten())
        model.add(Dense(4))
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model
        

def train_mimic(ref, agent,env,epoch,epsilon=0.1, decay=0.99, prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0
        
        agent.set_epsilon(epsilon)

        while not game_over:
            # The agent performs an action
            action = ref.act(state, train=False)

            
            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action, train=True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward
                
            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state,  action)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %%
epochs_train = 15
expert = agent
agent_n = CNN_Mimic(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=2)
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
train_mimic(expert,agent_n, env, epochs_train, prefix='cnn_train_mimick')
# Out:
# Epoch 000/015 | Loss 3.5020 | Win/lose count 17.0/29.10000000000001 (-12.100000000000009)
# Epoch 001/015 | Loss 2.1685 | Win/lose count 23.5/13.09999999999999 (10.40000000000001)
# Epoch 002/015 | Loss 2.7627 | Win/lose count 26.5/13.299999999999983 (13.200000000000017)
# Epoch 003/015 | Loss 2.4204 | Win/lose count 23.0/11.999999999999986 (11.000000000000014)
# Epoch 004/015 | Loss 2.2342 | Win/lose count 23.0/14.499999999999986 (8.500000000000014)
# Epoch 005/015 | Loss 2.6467 | Win/lose count 23.5/26.799999999999986 (-3.2999999999999865)
# Epoch 006/015 | Loss 2.9953 | Win/lose count 19.5/17.899999999999988 (1.600000000000012)
# Epoch 007/015 | Loss 3.2259 | Win/lose count 21.0/18.79999999999999 (2.20000000000001)
# Epoch 008/015 | Loss 2.4697 | Win/lose count 18.5/14.099999999999987 (4.400000000000013)
# Epoch 009/015 | Loss 2.6393 | Win/lose count 20.0/21.200000000000017 (-1.200000000000017)
# Epoch 010/015 | Loss 2.3050 | Win/lose count 23.0/10.199999999999987 (12.800000000000013)
# Epoch 011/015 | Loss 2.4317 | Win/lose count 27.5/9.999999999999991 (17.500000000000007)
# Epoch 012/015 | Loss 2.4834 | Win/lose count 29.0/11.89999999999999 (17.10000000000001)
# Epoch 013/015 | Loss 2.7454 | Win/lose count 25.5/13.19999999999999 (12.30000000000001)
# Epoch 014/015 | Loss 2.4348 | Win/lose count 27.5/13.699999999999989 (13.800000000000011)

# %%
# Evaluation
env_test = Environment(grid_size=size, max_time=T,temperature=0.3)
test(agent_n,env_test,epochs_test,prefix='cnn_test_mimick')
# Out:
# Win/lose count 15.5/4.0. Average score (11.5)
# Win/lose count 20.0/1.0. Average score (15.25)
# Win/lose count 26.0/1.0. Average score (18.5)
# Win/lose count 18.5/6.0. Average score (17.0)
# Win/lose count 26.0/6.0. Average score (17.6)
# Win/lose count 23.0/5.0. Average score (17.666666666666668)
# Win/lose count 18.5/12.0. Average score (16.071428571428573)
# Win/lose count 13.5/5.0. Average score (15.125)
# Win/lose count 19.0/4.0. Average score (15.11111111111111)
# Win/lose count 20.5/4.0. Average score (15.25)
# Win/lose count 19.5/1.0. Average score (15.545454545454545)
# Win/lose count 22.5/2.0. Average score (15.958333333333334)
# Win/lose count 25.5/6.0. Average score (16.23076923076923)
# Win/lose count 18.0/3.0. Average score (16.142857142857142)
# Win/lose count 16.0/2.0. Average score (16.0)
# Win/lose count 19.5/2.0. Average score (16.09375)
# Win/lose count 19.5/4.0. Average score (16.058823529411764)
# Win/lose count 19.0/4.0. Average score (16.0)
# Win/lose count 13.0/6.0. Average score (15.526315789473685)
# Win/lose count 6.0/1.0. Average score (15.0)
# Win/lose count 13.0/7.0. Average score (14.571428571428571)
# Win/lose count 19.5/6.0. Average score (14.522727272727273)
# Win/lose count 25.0/3.0. Average score (14.847826086956522)
# Win/lose count 18.5/7.0. Average score (14.708333333333334)
# Win/lose count 8.0/1.0. Average score (14.4)
# Win/lose count 26.0/2.0. Average score (14.76923076923077)
# Win/lose count 13.5/6.0. Average score (14.5)
# Win/lose count 22.0/3.0. Average score (14.660714285714286)
# Win/lose count 18.0/2.0. Average score (14.706896551724139)
# Win/lose count 19.0/4.0. Average score (14.716666666666667)
# Win/lose count 21.5/2.0. Average score (14.870967741935484)
# Win/lose count 15.0/1.0. Average score (14.84375)
# Win/lose count 12.5/1.0. Average score (14.742424242424242)
# Win/lose count 21.0/2.0. Average score (14.867647058823529)
# Win/lose count 11.5/1.0. Average score (14.742857142857142)
# Win/lose count 19.0/9.0. Average score (14.61111111111111)
# Win/lose count 21.5/5.0. Average score (14.662162162162161)
# Win/lose count 20.0/4.0. Average score (14.697368421052632)
# Win/lose count 13.0/1.0. Average score (14.628205128205128)
# Win/lose count 23.0/4.0. Average score (14.7375)
# Win/lose count 21.0/3.0. Average score (14.817073170731707)
# Win/lose count 21.0/2.0. Average score (14.916666666666666)
# Win/lose count 23.5/5.0. Average score (15.0)
# Win/lose count 13.5/8.0. Average score (14.784090909090908)
# Win/lose count 27.5/6.0. Average score (14.933333333333334)
# Win/lose count 21.0/7.0. Average score (14.91304347826087)
# Win/lose count 7.0/2.0. Average score (14.702127659574469)
# Win/lose count 12.5/3.0. Average score (14.59375)
# Win/lose count 23.5/5.0. Average score (14.673469387755102)
# Win/lose count 18.5/2.0. Average score (14.71)
# Final score: 14.71

# %% [markdown]
# The network learns faster but is not as performant as before.

# %% [markdown]
# ***
